# %%
import pandas as pd
import io

#データを読み込む
input_data = pd.read_csv("Airbnb_Open_Data.csv")
# Out:
# C:\Users\murakawa\AppData\Local\Temp\ipykernel_27028\4071948657.py:5: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   input_data = pd.read_csv("Airbnb_Open_Data.csv")

# %%
input_data.head(10)
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 6  1004650                                   BlissArtsSpace!  61300605564
# 7  1005202                                   BlissArtsSpace!  90821839709
# 8  1005754                   Large Furnished Room Near B'way  79384379533
# 9  1006307                Cozy Clean Guest Room - Family Apt  75527839483
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# ...

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
input_data.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year  minimum nights  number of reviews  \
# count      102385.000000   102190.000000      102416.000000
# mean         2012.487464        8.135845          27.483743
# std             5.765556       30.553781          49.508954
# min          2003.000000    -1223.000000           0.000000
# 25%          2007.000000        2.000000           1.000000
# ...

# %%
input_data['price'] = input_data['price'].str.replace('$', '')
input_data['price'] = input_data['price'].str.replace(',', '')
print(input_data.price)
# Out:
# 0          966
# 1          142
# 2          620
# 3          368
# 4          204
#           ...
# 102594     844
# 102595     837
# 102596     988
# 102597     546
# 102598    1032
# Name: price, Length: 102599, dtype: object
# C:\Users\murakawa\AppData\Local\Temp\ipykernel_27028\701048804.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   input_data['price'] = input_data['price'].str.replace('$', '')

# %%
input_data['service fee'] = input_data['service fee'].str.replace('$', '')
input_data['service fee'] = input_data['service fee'].str.replace(',', '')
print(input_data["service fee"])
# Out:
# 0         193
# 1          28
# 2         124
# 3          74
# 4          41
#           ...
# 102594    169
# 102595    167
# 102596    198
# 102597    109
# 102598    206
# Name: service fee, Length: 102599, dtype: object
# C:\Users\murakawa\AppData\Local\Temp\ipykernel_27028\856627994.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   input_data['service fee'] = input_data['service fee'].str.replace('$', '')

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
input_data['price'] = pd.to_numeric(input_data['price'], errors="coerce")
input_data['service fee'] = pd.to_numeric(input_data['service fee'], errors="coerce")
# input_data['price'] = input_data['price'].astype('int')
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
input_data.describe()
# Out:
#                  id       host id            lat           long  \
# count  1.025990e+05  1.025990e+05  102591.000000  102591.000000
# mean   2.914623e+07  4.925411e+10      40.728094     -73.949644
# std    1.625751e+07  2.853900e+10       0.055857       0.049521
# min    1.001254e+06  1.236005e+08      40.499790     -74.249840
# 25%    1.508581e+07  2.458333e+10      40.688740     -73.982580
# 50%    2.913660e+07  4.911774e+10      40.722290     -73.954440
# 75%    4.320120e+07  7.399650e+10      40.762760     -73.932350
# max    5.736742e+07  9.876313e+10      40.916970     -73.705220
#
#        Construction year          price    service fee  minimum nights  \
# count      102385.000000  102352.000000  102326.000000   102190.000000
# mean         2012.487464     625.293536     125.026924        8.135845
# std             5.765556     331.671614      66.325739       30.553781
# min          2003.000000      50.000000      10.000000    -1223.000000
# ...

# %%
#価格の平均をもとめる
print(input_data.price.mean())
#価格のメディアン値をもとめる
print(input_data.price.median())
#価格の分散をもとめる
print(input_data.price.var())
#価格の標準偏差をもとめる
print(input_data.price.std())
#価格の最大値をもとめる
print(input_data.price.max())
#価格の最小値をもとめる
print(input_data.price.min())
# Out:
# 625.2935360325152
# 624.0
# 110006.0592178257
# 331.6716135243197
# 1200.0
# 50.0

# %%
print(input_data["room type"])
# Out:
# 0            Private room
# 1         Entire home/apt
# 2            Private room
# 3         Entire home/apt
# 4         Entire home/apt
#                ...
# 102594       Private room
# 102595       Private room
# 102596       Private room
# 102597    Entire home/apt
# 102598    Entire home/apt
# Name: room type, Length: 102599, dtype: object

# %%
#ルームタイプごとに、価格の平均をもとめる
print(input_data.groupby('room type')['price'].mean())
#ルームタイプごとに、価格のメディアン値をもとめる
print(input_data.groupby('room type')['price'].median())
#ルームタイプごとに、価格の分散をもとめる
print(input_data.groupby('room type')['price'].var())
#ルームタイプごとに、価格の標準偏差をもとめる
print(input_data.groupby('room type')['price'].std())
#ルームタイプごとに、価格の最大値をもとめる
print(input_data.groupby('room type')['price'].max())
#ルームタイプごとに、価格の最小値をもとめる
print(input_data.groupby('room type')['price'].min())
# Out:
# room type
# Entire home/apt    625.082232
# Hotel room         668.465517
# Private room       625.007363
# Shared room        634.132101
# Name: price, dtype: float64
# room type
# Entire home/apt    624.0
# Hotel room         644.5
# Private room       623.0
# Shared room        651.0
# Name: price, dtype: float64
# room type
# Entire home/apt    110033.655997
# Hotel room          96637.972714
# Private room       109780.979558
# Shared room        114718.791292
# Name: price, dtype: float64
# room type
# Entire home/apt    331.713213
# Hotel room         310.866487
# Private room       331.332129
# Shared room        338.701626
# Name: price, dtype: float64
# room type
# Entire home/apt    1200.0
# Hotel room         1193.0
# Private room       1200.0
# Shared room        1199.0
# Name: price, dtype: float64
# room type
# Entire home/apt    50.0
# Hotel room         50.0
# Private room       50.0
# Shared room        50.0
# Name: price, dtype: float64

# %%
#価格の平均をもとめる
print((input_data["price"]+input_data["service fee"]).mean())
#価格のメディアン値をもとめる
print((input_data["price"]+input_data["service fee"]).median())
#価格の分散をもとめる
print((input_data["price"]+input_data["service fee"]).var())
#価格の標準偏差をもとめる
print((input_data["price"]+input_data["service fee"]).std())
#価格の最大値をもとめる
print((input_data["price"]+input_data["service fee"]).max())
#価格の最小値をもとめる
print((input_data["price"]+input_data["service fee"]).min())
# Out:
# 750.2266900394661
# 749.0
# 158390.94375371005
# 397.9835973425413
# 1440.0
# 60.0

# %%
input_data["total price"] = input_data["price"]+input_data["service fee"]

# %%
print(input_data["price"])
print(input_data["service fee"])
print(input_data["total price"])
# Out:
# 0          966.0
# 1          142.0
# 2          620.0
# 3          368.0
# 4          204.0
#            ...
# 102594     844.0
# 102595     837.0
# 102596     988.0
# 102597     546.0
# 102598    1032.0
# Name: price, Length: 102599, dtype: float64
# 0         193.0
# 1          28.0
# 2         124.0
# 3          74.0
# 4          41.0
#           ...
# 102594    169.0
# 102595    167.0
# 102596    198.0
# 102597    109.0
# 102598    206.0
# Name: service fee, Length: 102599, dtype: float64
# 0         1159.0
# 1          170.0
# 2          744.0
# 3          442.0
# 4          245.0
#            ...
# 102594    1013.0
# 102595    1004.0
# 102596    1186.0
# 102597     655.0
# 102598    1238.0
# Name: total price, Length: 102599, dtype: float64

# %%
import matplotlib.pyplot as plt

#価格(price) についてヒストグラムを描く
plt.hist(input_data.price)
plt.xlabel('price')
plt.ylabel('count')
plt.grid(True)

# %%
import matplotlib.pyplot as plt
import scipy.stats

plt.scatter(input_data["minimum nights"],input_data.price, s=50, c="blue", alpha=0.3, linewidths=1, edgecolors="blue")
plt.title('minimum nights and Price')
plt.ylabel('Price')
plt.xlabel('Minimum Nights')
# Out:
# Text(0.5, 0, 'Minimum Nights')

# %%
import seaborn as sns
sns.jointplot(data=input_data, x="minimum nights", y="price")

# %%
import numpy as np

#モデルで利用する変数を接合し, ひとつの DataFrame にする
#読み込むデータを変えれば, 説明変数や被説明変数を変えることが可能
x_list = pd.concat([input_data.price, input_data["Construction year"],input_data["number of reviews"], input_data["calculated host listings count"], input_data["reviews per month"]], axis=1)

#pairplotをプロットする
sns.pairplot(x_list, kind='reg')
